# %%
from doped.generation import DefectsGenerator

defect_gen = DefectsGenerator("CdTe/relaxed_primitive_POSCAR")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1478017/444656226.py in <module>
# ----> 1 from doped.generation import DefectsGenerator
#       2
#       3 defect_gen = DefectsGenerator("../examples/CdTe/relaxed_primitive_POSCAR")
#
# ~/.local/lib/python3.10/site-packages/doped/__init__.py in <module>
#      16
#      17 from pymatgen.io.vasp.inputs import UnknownPotcarWarning
# ---> 18 from pymatgen.io.vasp.sets import BadInputSetWarning
#      19
#      20 try:
#
# ~/.local/lib/python3.10/site-packages/pymatgen/io/vasp/__init__.py in <module>
#       9
#      10 from .inputs import Incar, Kpoints, Poscar, Potcar, PotcarSingle, VaspInput
# ---> 11 from .outputs import (
#      12     BSVasprun,
#      13     Chgcar,
#
# ~/.local/lib/python3.10/site-packages/pymatgen/io/vasp/outputs.py in <module>
#      47
#      48 try:
# ---> 49     import h5py
#      50 except ImportError:
#      51     h5py = None
#
# /usr/lib/python3/dist-packages/h5py/__init__.py in <module>
#      19         from . import _debian_h5py_serial as _h5py
#      20 else:
# ---> 21     from . import _debian_h5py_serial as _h5py
#      22
#      23 __version__ = _h5py.__version__
#
# /usr/lib/python3/dist-packages/h5py/_debian_h5py_serial/__init__.py in <module>
#      23 # We tried working around this by using "package_dir" but that breaks Cython.
#      24 try:
# ---> 25     from . import _errors
#      26 except ImportError:
#      27     import os.path as _op
#
# h5py/_debian_h5py_serial/_errors.pyx in init h5py._debian_h5py_serial._errors()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject
